# %%
## Load key variables
import os
from dotenv import load_dotenv, dotenv_values

# %%
## Set up connection with .env
load_dotenv()
# Out:
# True

# %% [markdown]
# ![image.png](attachment:ccb94f19-7e48-4b09-9c2a-24c378567425.png)

# %% [markdown]
# ![image.png](attachment:bdc6aa0d-6dd9-4ab6-9fbf-9848a926d224.png)

# %%
print(os.getenv("my_secret_key"))
# Out:
# Kevin Lee
